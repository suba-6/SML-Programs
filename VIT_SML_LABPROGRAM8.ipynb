# %% [markdown]
# Program 8: A company collects data on employees' salaries and records their education level as a categorical variable with three levels: "High School", "Bachelor's", and "Master's". Fit a multiple linear regression model to predict salary using education level (as a factor variable) and years of experience. Interpret the coefficients for the education levels in the regression model.

# %%
import pandas as pd 
import statsmodels.formula.api as smf
# Out:
# C:\Users\rosli\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\rosli\anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\rosli\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\rosli\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# Example dataset
data = pd.DataFrame({ "Salary": [30000, 35000, 40000, 42000, 50000, 55000, 60000, 62000, 70000], "Education": ["High School", "High School", "Bachelor's", "Bachelor's", "Master's", "Master's", "High School", "Bachelor's", "Master's"], "Experience": [1, 3, 2, 5, 4, 6, 8, 7, 10] })

# %%
data
# Out:
#    Salary    Education  Experience
# 0   30000  High School           1
# 1   35000  High School           3
# 2   40000   Bachelor's           2
# 3   42000   Bachelor's           5
# 4   50000     Master's           4
# 5   55000     Master's           6
# 6   60000  High School           8
# 7   62000   Bachelor's           7
# 8   70000     Master's          10

# %%
# Fit regression model
# C(Education) tells statsmodels to treat Education as a categorical (factor) variable 
model = smf.ols("Salary ~ Experience + C(Education)", data=data).fit()

# %%
# Show results
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.928
# Model:                            OLS   Adj. R-squared:                  0.886
# Method:                 Least Squares   F-statistic:                     21.64
# Date:                Tue, 15 Sep 2026   Prob (F-statistic):            0.00271
# Time:                        09:04:51   Log-Likelihood:                -85.952
# No. Observations:                   9   AIC:                             179.9
# Df Residuals:                       5   BIC:                             180.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                    2.925e+04   3851.184      7.596      0.001    1.94e+04    3.92e+04
# ...
