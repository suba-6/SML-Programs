# %% [markdown]
# # Lab Program 1:A dataset contains the prices of houses in a city. Find the 25th and 75th percentiles and calculate the Inter quartile range (IQR). How does the IQR help in understanding the price variability

# %%
import pandas as pd 
# Load the dataset (assuming it's in a CSV file named 'house_prices.csv' with a 'price' column) 
df = pd.read_csv('house.csv')

# %%
df
# Out:
#       square_feet  num_rooms  age  distance_to_city(km)          price
# 0     2248.357077          3   92             22.997972  200374.090400
# 1     1930.867849          2   22             13.984254  268784.847300
# 2     2323.844269          6   33             21.500945  315020.857700
# 3     2761.514928          3   63             10.343638  355111.468500
# 4     1882.923313          7   54             25.485200  234197.123900
# ...           ...        ...  ...                   ...            ...
# 9995  2650.551032          7    9             18.126034  431344.267800
# 9996  1000.827516          2   53             24.479692    6650.271134
# 9997  1647.341638          5   80              2.189312  233698.384300
# 9998  2247.882787          6   73             27.931014  280766.827400
# 9999  2322.194227          7   73             10.595721  342895.309100
#
# [10000 rows x 5 columns]

# %%
# Calculate the 25th percentile (Q1) q1 = df['price'].quantile(0.25) 
# Calculate the 25th percentile (Q1)
q1 = df['price'].quantile(0.25)
q3 = df['price'].quantile(0.75)
IQR= q3-q1
print("Q1 (25th percentile):", q1)
print("Q1 (75th percentile):", q3)
print("IQR:", IQR)
# Out:
# Q1 (25th percentile): 196791.51069999998
# Q1 (75th percentile): 330445.58187500003
# IQR: 133654.07117500005

# %% [markdown]
# Q1 → The value below which 25% of the data lies.
# Q3 → The value below which 75% of the data lies.
# IQR = Q3 - Q1 → The range of the middle 50% of the data.
